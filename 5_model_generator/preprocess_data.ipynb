# %%
import pandas as pd

# %% [markdown]
# ## 1. Dataset de precios de canasta básica
# A través de la página de la SEDECO se puede descargar el dataset de precios de la canasta básica, el cual contiene los precios de los productos que conforman la canasta básica desde el 01 de Enero de 2022. El dataset se encuentra en formato .csv y contiene cinco columnas: producto, unidad de medida, precio mínimo, precio máxima y fecha.

# %%
# Lee el archivo csv de precios de canasta básica
precio_canasta = pd.read_csv('../1_precios_canasta/canasta_basica.csv')
precio_canasta
# Out:
#                  Producto Unidad de Medida Precio Mínimo Precio Máximo  \
# 0            Aceite Mixto           1   Kg         $0.00         $0.00
# 1             Arroz largo             1 Kg         $0.00         $0.00
# 2         Azúcar Estándar             1 Kg         $0.00         $0.00
# 3         Harina de Trigo           1   Kg         $0.00         $0.00
# 4     Frijol Flor de Mayo           1   Kg         $0.00         $0.00
# ...                   ...              ...           ...           ...
# 8283       Lechuga romana             1 Kg        $10.00        $15.00
# 8284           Papa alpha             1 Kg        $21.00        $25.00
# 8285               Pepino             1 Kg        $10.00        $16.00
# 8286         Tomate verde             1 Kg        $13.00        $18.00
# 8287    Zanahoria mediana             1 Kg        $10.00        $15.00
#
#            Fecha
# 0     2022-01-01
# 1     2022-01-01
# 2     2022-01-01
# 3     2022-01-01
# 4     2022-01-01
# ...

# %% [markdown]
# ## 2. Dataset de recetas desde un archivo CSV
# Desde una fuente de datos en formato CSV, se obtiene un DataFrame de Pandas con las recetas.

# %%
# Read pdf into list of DataFrame
train = pd.read_csv('../2_recetas/recipes.csv')
train
# Out:
#                                             Receta  Personas Cantidad  Unidad  \
# 0    Setas a la mexicana. Receta tradicional fácil         4      300  gramos
# 1    Setas a la mexicana. Receta tradicional fácil         4      300  gramos
# 2    Setas a la mexicana. Receta tradicional fácil         4        1  diente
# 3    Setas a la mexicana. Receta tradicional fácil         4        3  piezas
# 4    Setas a la mexicana. Receta tradicional fácil         4        1   pieza
# ..                                             ...       ...      ...     ...
# 576       Tortitas de atún. Receta mexicana rápida         4        2  piezas
# 577       Tortitas de atún. Receta mexicana rápida         4        1    taza
# 578       Tortitas de atún. Receta mexicana rápida         4        1   gusto
# 579       Tortitas de atún. Receta mexicana rápida         4        1   gusto
# 580       Tortitas de atún. Receta mexicana rápida         4        1   gusto
#
#     Ingrediente
# ...
